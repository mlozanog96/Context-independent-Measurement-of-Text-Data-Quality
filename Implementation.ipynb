# %% [markdown]
# # Implementation

# %% [markdown]
# ## Libraries and Settings

# %%
import pandas as pd

from utils import abbreviation_metric, spelling_mistake_metric, unknown_word_metric, grammatical_sentence_metric, lexical_density_metric, lexical_diversity_metric, stop_word_metric, average_sentence_length_metric, uppercased_word_metric, symbol_punctuation_metric, column_average, processed_text

# Store/read data
import pickle
from pathlib import Path

# Sentiment analysis for English
from nltk.sentiment import SentimentIntensityAnalyzer
import nltk
nltk.download('vader_lexicon')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\maryl\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\maryl\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# C:\Users\maryl\anaconda3\lib\site-packages\paramiko\transport.py:219: CryptographyDeprecationWarning: Blowfish has been deprecated
#   "class": algorithms.Blowfish,
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\maryl\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %% [markdown]
# ## Load Dataset

# %%
# Upload pickle file with dataset
with open(Path('dataset.pkl').parent/'Data/Processed data/dataset.pkl', 'rb') as file:
        df = pickle.load(file)

# %%
df.shape
# Out:
# (5000, 5)

# %% [markdown]
# ## Text Processing

# %%
# Function to create processed text column
processed_text(df,'text')
# Out:
#                                                   text human_sentiment  \
# 0    @switchfoot http://twitpic.com/2y1zl - Awww, t...        negative
# 1    is upset that he can't update his Facebook by ...        negative
# 2    @Kenichan I dived many times for the ball. Man...         neutral
# 3      my whole body feels itchy and like its on fire         negative
# 4    @nationwideclass no, it's not behaving at all....         neutral
# ..                                                 ...             ...
# 995  i love it! the berry scent is faint and delici...        positive
# 996  I use this almost every night and I wake up wi...         neutral
# 997  This mask is great! It smells delicious and my...        positive
# 998  These is similar to Vaseline with a tint of co...        negative
# 999  Feels like Vaseline, and has titanium dioxide ...        negative
#
#     text_type  length length_classification  \
# 0     twitter     115                medium
# 1     twitter     111                medium
# 2     twitter      89                medium
# 3     twitter      47                 short
# 4     twitter     111                medium
# ..        ...     ...                   ...
# 995    review     238                medium
# 996    review     511                  long
# 997    review     182                medium
# 998    review     151                medium
# 999    review     269                  long
#
#                                         processed_text
# 0          aww bummer shoulda got david carr third day
# 1    upset cannot update facebook texting might cry...
# 2    dived many times for the ball managed save the...
# 3                     whole body feels itchy like fire
# 4                  no not behaving mad cannot see over
# ..                                                 ...
# 995  love the berry scent faint delicious the produ...
# 996  use almost every night wake little left over t...
# 997  mask great smells delicious lips feel plump sm...
# 998  similar vaseline tint color but prettier jar o...
# 999  feels like vaseline titanium dioxide might car...
#
# [5000 rows x 6 columns]

# %%
# Create pickle file
picklefile = open('Data/Processed Data/processed_dataset.pkl', 'wb')
pickle.dump(df, picklefile)
picklefile.close()

# %% [markdown]
# ## Context-independent Metrics of Text Data Quality

# %%
# Upload pickle file with dataset
with open(Path('processed_dataset').parent/'Data/Processed Data/processed_dataset.pkl', 'rb') as file:
        df = pickle.load(file)

# %% [markdown]
# ### Metric 1: Abbreviation metric

# %%
abbreviation_metric(df,'text','m1_abbrv_txt')
abbreviation_metric(df,'processed_text','m1_abbrv_ptxt')
# Out:
#                                                   text human_sentiment  \
# 0    @switchfoot http://twitpic.com/2y1zl - Awww, t...        negative
# 1    is upset that he can't update his Facebook by ...        negative
# 2    @Kenichan I dived many times for the ball. Man...         neutral
# 3      my whole body feels itchy and like its on fire         negative
# 4    @nationwideclass no, it's not behaving at all....         neutral
# ..                                                 ...             ...
# 995  i love it! the berry scent is faint and delici...        positive
# 996  I use this almost every night and I wake up wi...         neutral
# 997  This mask is great! It smells delicious and my...        positive
# 998  These is similar to Vaseline with a tint of co...        negative
# 999  Feels like Vaseline, and has titanium dioxide ...        negative
#
#     text_type  length length_classification  \
# 0     twitter     115                medium
# 1     twitter     111                medium
# 2     twitter      89                medium
# 3     twitter      47                 short
# 4     twitter     111                medium
# ..        ...     ...                   ...
# 995    review     238                medium
# 996    review     511                  long
# 997    review     182                medium
# 998    review     151                medium
# 999    review     269                  long
#
#                                         processed_text  m1_abbrv_txt  \
# 0          aww bummer shoulda got david carr third day           1.0
# 1    upset cannot update facebook texting might cry...           1.0
# 2    dived many times for the ball managed save the...           1.0
# 3                     whole body feels itchy like fire           1.0
# 4                  no not behaving mad cannot see over           1.0
# ..                                                 ...           ...
# 995  love the berry scent faint delicious the produ...           1.0
# 996  use almost every night wake little left over t...           1.0
# 997  mask great smells delicious lips feel plump sm...           1.0
# 998  similar vaseline tint color but prettier jar o...           1.0
# 999  feels like vaseline titanium dioxide might car...           1.0
#
#      m1_abbrv_ptxt
# 0              1.0
# 1              1.0
# 2              1.0
# 3              1.0
# 4              1.0
# ..             ...
# 995            1.0
# 996            1.0
# 997            1.0
# 998            1.0
# 999            1.0
#
# [5000 rows x 8 columns]

# %% [markdown]
# ### Metric 2: Spelling mistake metric

# %%
spelling_mistake_metric(df,'text','m2_sp_mstke_txt')
spelling_mistake_metric(df,'processed_text','m2_sp_mstke_ptxt')
# Out:
#                                                   text human_sentiment  \
# 0    @switchfoot http://twitpic.com/2y1zl - Awww, t...        negative
# 1    is upset that he can't update his Facebook by ...        negative
# 2    @Kenichan I dived many times for the ball. Man...         neutral
# 3      my whole body feels itchy and like its on fire         negative
# 4    @nationwideclass no, it's not behaving at all....         neutral
# ..                                                 ...             ...
# 995  i love it! the berry scent is faint and delici...        positive
# 996  I use this almost every night and I wake up wi...         neutral
# 997  This mask is great! It smells delicious and my...        positive
# 998  These is similar to Vaseline with a tint of co...        negative
# 999  Feels like Vaseline, and has titanium dioxide ...        negative
#
#     text_type  length length_classification  \
# 0     twitter     115                medium
# 1     twitter     111                medium
# 2     twitter      89                medium
# 3     twitter      47                 short
# 4     twitter     111                medium
# ..        ...     ...                   ...
# 995    review     238                medium
# 996    review     511                  long
# 997    review     182                medium
# 998    review     151                medium
# 999    review     269                  long
#
#                                         processed_text  m1_abbrv_txt  \
# 0          aww bummer shoulda got david carr third day           1.0
# 1    upset cannot update facebook texting might cry...           1.0
# 2    dived many times for the ball managed save the...           1.0
# 3                     whole body feels itchy like fire           1.0
# 4                  no not behaving mad cannot see over           1.0
# ..                                                 ...           ...
# 995  love the berry scent faint delicious the produ...           1.0
# 996  use almost every night wake little left over t...           1.0
# 997  mask great smells delicious lips feel plump sm...           1.0
# 998  similar vaseline tint color but prettier jar o...           1.0
# 999  feels like vaseline titanium dioxide might car...           1.0
#
#      m1_abbrv_ptxt  m2_sp_mstke_txt  m2_sp_mstke_ptxt
# 0              1.0         0.875000               1.0
# 1              1.0         1.000000               1.0
# 2              1.0         1.000000               1.0
# 3              1.0         1.000000               1.0
# 4              1.0         1.000000               1.0
# ..             ...              ...               ...
# 995            1.0         0.977273               1.0
# 996            1.0         0.979381               1.0
# 997            1.0         1.000000               1.0
# 998            1.0         0.933333               1.0
# 999            1.0         0.955556               1.0
#
# [5000 rows x 10 columns]

# %% [markdown]
# ### Metric 3: Unknown words metric

# %%
unknown_word_metric(df,'text','m3_unk_wds_txt')
unknown_word_metric(df,'processed_text','m3_unk_wds_ptxt')
# Out:
#                                                   text human_sentiment  \
# 0    @switchfoot http://twitpic.com/2y1zl - Awww, t...        negative
# 1    is upset that he can't update his Facebook by ...        negative
# 2    @Kenichan I dived many times for the ball. Man...         neutral
# 3      my whole body feels itchy and like its on fire         negative
# 4    @nationwideclass no, it's not behaving at all....         neutral
# ..                                                 ...             ...
# 995  i love it! the berry scent is faint and delici...        positive
# 996  I use this almost every night and I wake up wi...         neutral
# 997  This mask is great! It smells delicious and my...        positive
# 998  These is similar to Vaseline with a tint of co...        negative
# 999  Feels like Vaseline, and has titanium dioxide ...        negative
#
#     text_type  length length_classification  \
# 0     twitter     115                medium
# 1     twitter     111                medium
# 2     twitter      89                medium
# 3     twitter      47                 short
# 4     twitter     111                medium
# ..        ...     ...                   ...
# 995    review     238                medium
# 996    review     511                  long
# 997    review     182                medium
# 998    review     151                medium
# 999    review     269                  long
#
#                                         processed_text  m1_abbrv_txt  \
# 0          aww bummer shoulda got david carr third day           1.0
# 1    upset cannot update facebook texting might cry...           1.0
# 2    dived many times for the ball managed save the...           1.0
# 3                     whole body feels itchy like fire           1.0
# 4                  no not behaving mad cannot see over           1.0
# ..                                                 ...           ...
# 995  love the berry scent faint delicious the produ...           1.0
# 996  use almost every night wake little left over t...           1.0
# 997  mask great smells delicious lips feel plump sm...           1.0
# 998  similar vaseline tint color but prettier jar o...           1.0
# 999  feels like vaseline titanium dioxide might car...           1.0
#
#      m1_abbrv_ptxt  m2_sp_mstke_txt  m2_sp_mstke_ptxt  m3_unk_wds_txt  \
# 0              1.0         0.875000               1.0        0.736842
# 1              1.0         1.000000               1.0        0.952381
# 2              1.0         1.000000               1.0        1.000000
# 3              1.0         1.000000               1.0        1.000000
# 4              1.0         1.000000               1.0        0.857143
# ..             ...              ...               ...             ...
# 995            1.0         0.977273               1.0        0.977778
# 996            1.0         0.979381               1.0        0.969072
# 997            1.0         1.000000               1.0        1.000000
# 998            1.0         0.933333               1.0        0.900000
# 999            1.0         0.955556               1.0        0.955556
#
#      m3_unk_wds_ptxt
# 0                1.0
# 1                1.0
# 2                1.0
# 3                1.0
# 4                1.0
# ..               ...
# 995              1.0
# 996              1.0
# 997              1.0
# 998              1.0
# 999              1.0
#
# [5000 rows x 12 columns]

# %% [markdown]
# ### Metric 4: Grammatical sentence metric

# %%
grammatical_sentence_metric(df, 'text','m4_gram_sent_txt')
grammatical_sentence_metric(df, 'processed_text','m4_gram_sent_ptxt')

# %% [markdown]
# ### Metric 5: Lexical density metric

# %%
lexical_density_metric(df, 'text','m5_lex_den_txt')
lexical_density_metric(df, 'processed_text','m5_lex_den_ptxt')
# Out:
#                                                   text human_sentiment  \
# 0    @switchfoot http://twitpic.com/2y1zl - Awww, t...        negative
# 1    is upset that he can't update his Facebook by ...        negative
# 2    @Kenichan I dived many times for the ball. Man...         neutral
# 3      my whole body feels itchy and like its on fire         negative
# 4    @nationwideclass no, it's not behaving at all....         neutral
# ..                                                 ...             ...
# 995  i love it! the berry scent is faint and delici...        positive
# 996  I use this almost every night and I wake up wi...         neutral
# 997  This mask is great! It smells delicious and my...        positive
# 998  These is similar to Vaseline with a tint of co...        negative
# 999  Feels like Vaseline, and has titanium dioxide ...        negative
#
#     text_type  length length_classification  \
# 0     twitter     115                medium
# 1     twitter     111                medium
# 2     twitter      89                medium
# 3     twitter      47                 short
# 4     twitter     111                medium
# ..        ...     ...                   ...
# 995    review     238                medium
# 996    review     511                  long
# 997    review     182                medium
# 998    review     151                medium
# 999    review     269                  long
#
#                                         processed_text  m1_abbrv_txt  \
# 0          aww bummer shoulda got david carr third day           1.0
# 1    upset cannot update facebook texting might cry...           1.0
# 2    dived many times for the ball managed save the...           1.0
# 3                     whole body feels itchy like fire           1.0
# 4                  no not behaving mad cannot see over           1.0
# ..                                                 ...           ...
# 995  love the berry scent faint delicious the produ...           1.0
# 996  use almost every night wake little left over t...           1.0
# 997  mask great smells delicious lips feel plump sm...           1.0
# 998  similar vaseline tint color but prettier jar o...           1.0
# 999  feels like vaseline titanium dioxide might car...           1.0
#
#      m1_abbrv_ptxt  m2_sp_mstke_txt  m2_sp_mstke_ptxt  m3_unk_wds_txt  \
# 0              1.0         0.875000               1.0        0.736842
# 1              1.0         1.000000               1.0        0.952381
# 2              1.0         1.000000               1.0        1.000000
# 3              1.0         1.000000               1.0        1.000000
# 4              1.0         1.000000               1.0        0.857143
# ..             ...              ...               ...             ...
# 995            1.0         0.977273               1.0        0.977778
# 996            1.0         0.979381               1.0        0.969072
# 997            1.0         1.000000               1.0        1.000000
# 998            1.0         0.933333               1.0        0.900000
# 999            1.0         0.955556               1.0        0.955556
#
#      m3_unk_wds_ptxt  m4_gram_sent_txt  m4_gram_sent_ptxt  m5_lex_den_txt  \
# 0                1.0          0.000000                0.0        0.454545
# 1                1.0          0.000000                0.0        0.363636
# 2                1.0          0.333333                1.0        0.500000
# 3                1.0          0.000000                0.0        0.500000
# 4                1.0          0.000000                0.0        0.500000
# ..               ...               ...                ...             ...
# 995              1.0          0.500000                1.0        0.568182
# 996              1.0          0.000000                0.0        0.489796
# 997              1.0          0.333333                1.0        0.447368
# 998              1.0          0.333333                1.0        0.333333
# 999              1.0          0.333333                0.0        0.488889
#
#      m5_lex_den_ptxt
# 0           0.625000
# 1           0.833333
# 2           0.692308
# 3           0.833333
# 4           0.428571
# ..               ...
# 995         0.846154
# 996         0.775862
# 997         0.761905
# 998         0.611111
# 999         0.777778
#
# [5000 rows x 16 columns]

# %% [markdown]
# ### Metric 6: Lexical diversity metric

# %%
lexical_diversity_metric(df, 'text','m6_lex_div_txt')
lexical_diversity_metric(df, 'processed_text','m6_lex_div_ptxt')
# Out:
#                                                   text human_sentiment  \
# 0    @switchfoot http://twitpic.com/2y1zl - Awww, t...        negative
# 1    is upset that he can't update his Facebook by ...        negative
# 2    @Kenichan I dived many times for the ball. Man...         neutral
# 3      my whole body feels itchy and like its on fire         negative
# 4    @nationwideclass no, it's not behaving at all....         neutral
# ..                                                 ...             ...
# 995  i love it! the berry scent is faint and delici...        positive
# 996  I use this almost every night and I wake up wi...         neutral
# 997  This mask is great! It smells delicious and my...        positive
# 998  These is similar to Vaseline with a tint of co...        negative
# 999  Feels like Vaseline, and has titanium dioxide ...        negative
#
#     text_type  length length_classification  \
# 0     twitter     115                medium
# 1     twitter     111                medium
# 2     twitter      89                medium
# 3     twitter      47                 short
# 4     twitter     111                medium
# ..        ...     ...                   ...
# 995    review     238                medium
# 996    review     511                  long
# 997    review     182                medium
# 998    review     151                medium
# 999    review     269                  long
#
#                                         processed_text  m1_abbrv_txt  \
# 0          aww bummer shoulda got david carr third day           1.0
# 1    upset cannot update facebook texting might cry...           1.0
# 2    dived many times for the ball managed save the...           1.0
# 3                     whole body feels itchy like fire           1.0
# 4                  no not behaving mad cannot see over           1.0
# ..                                                 ...           ...
# 995  love the berry scent faint delicious the produ...           1.0
# 996  use almost every night wake little left over t...           1.0
# 997  mask great smells delicious lips feel plump sm...           1.0
# 998  similar vaseline tint color but prettier jar o...           1.0
# 999  feels like vaseline titanium dioxide might car...           1.0
#
#      m1_abbrv_ptxt  m2_sp_mstke_txt  m2_sp_mstke_ptxt  m3_unk_wds_txt  \
# 0              1.0         0.875000               1.0        0.736842
# 1              1.0         1.000000               1.0        0.952381
# 2              1.0         1.000000               1.0        1.000000
# 3              1.0         1.000000               1.0        1.000000
# 4              1.0         1.000000               1.0        0.857143
# ..             ...              ...               ...             ...
# 995            1.0         0.977273               1.0        0.977778
# 996            1.0         0.979381               1.0        0.969072
# 997            1.0         1.000000               1.0        1.000000
# 998            1.0         0.933333               1.0        0.900000
# 999            1.0         0.955556               1.0        0.955556
#
#      m3_unk_wds_ptxt  m4_gram_sent_txt  m4_gram_sent_ptxt  m5_lex_den_txt  \
# 0                1.0          0.000000                0.0        0.454545
# 1                1.0          0.000000                0.0        0.363636
# 2                1.0          0.333333                1.0        0.500000
# 3                1.0          0.000000                0.0        0.500000
# 4                1.0          0.000000                0.0        0.500000
# ..               ...               ...                ...             ...
# 995              1.0          0.500000                1.0        0.568182
# 996              1.0          0.000000                0.0        0.489796
# 997              1.0          0.333333                1.0        0.447368
# 998              1.0          0.333333                1.0        0.333333
# 999              1.0          0.333333                0.0        0.488889
#
#      m5_lex_den_ptxt  m6_lex_div_txt  m6_lex_div_ptxt
# 0           0.625000        1.000000         1.000000
# 1           0.833333        1.000000         1.000000
# 2           0.692308        1.000000         0.923077
# 3           0.833333        1.000000         1.000000
# 4           0.428571        1.000000         1.000000
# ..               ...             ...              ...
# 995         0.846154        0.866667         0.923077
# 996         0.775862        0.762887         0.844828
# 997         0.761905        0.868421         0.904762
# 998         0.611111        0.933333         0.944444
# 999         0.777778        0.844444         0.962963
#
# [5000 rows x 18 columns]

# %% [markdown]
# ### Metric 7: Stop word metric

# %%
stop_word_metric(df,'text','m7_stp_wd_txt')
stop_word_metric(df,'processed_text','m7_stp_wd_ptxt')
# Out:
#                                                   text human_sentiment  \
# 0    @switchfoot http://twitpic.com/2y1zl - Awww, t...        negative
# 1    is upset that he can't update his Facebook by ...        negative
# 2    @Kenichan I dived many times for the ball. Man...         neutral
# 3      my whole body feels itchy and like its on fire         negative
# 4    @nationwideclass no, it's not behaving at all....         neutral
# ..                                                 ...             ...
# 995  i love it! the berry scent is faint and delici...        positive
# 996  I use this almost every night and I wake up wi...         neutral
# 997  This mask is great! It smells delicious and my...        positive
# 998  These is similar to Vaseline with a tint of co...        negative
# 999  Feels like Vaseline, and has titanium dioxide ...        negative
#
#     text_type  length length_classification  \
# 0     twitter     115                medium
# 1     twitter     111                medium
# 2     twitter      89                medium
# 3     twitter      47                 short
# 4     twitter     111                medium
# ..        ...     ...                   ...
# 995    review     238                medium
# 996    review     511                  long
# 997    review     182                medium
# 998    review     151                medium
# 999    review     269                  long
#
#                                         processed_text  m1_abbrv_txt  \
# 0          aww bummer shoulda got david carr third day           1.0
# 1    upset cannot update facebook texting might cry...           1.0
# 2    dived many times for the ball managed save the...           1.0
# 3                     whole body feels itchy like fire           1.0
# 4                  no not behaving mad cannot see over           1.0
# ..                                                 ...           ...
# 995  love the berry scent faint delicious the produ...           1.0
# 996  use almost every night wake little left over t...           1.0
# 997  mask great smells delicious lips feel plump sm...           1.0
# 998  similar vaseline tint color but prettier jar o...           1.0
# 999  feels like vaseline titanium dioxide might car...           1.0
#
#      m1_abbrv_ptxt  m2_sp_mstke_txt  m2_sp_mstke_ptxt  m3_unk_wds_txt  \
# 0              1.0         0.875000               1.0        0.736842
# 1              1.0         1.000000               1.0        0.952381
# 2              1.0         1.000000               1.0        1.000000
# 3              1.0         1.000000               1.0        1.000000
# 4              1.0         1.000000               1.0        0.857143
# ..             ...              ...               ...             ...
# 995            1.0         0.977273               1.0        0.977778
# 996            1.0         0.979381               1.0        0.969072
# 997            1.0         1.000000               1.0        1.000000
# 998            1.0         0.933333               1.0        0.900000
# 999            1.0         0.955556               1.0        0.955556
#
#      m3_unk_wds_ptxt  m4_gram_sent_txt  m4_gram_sent_ptxt  m5_lex_den_txt  \
# 0                1.0          0.000000                0.0        0.454545
# 1                1.0          0.000000                0.0        0.363636
# 2                1.0          0.333333                1.0        0.500000
# 3                1.0          0.000000                0.0        0.500000
# 4                1.0          0.000000                0.0        0.500000
# ..               ...               ...                ...             ...
# 995              1.0          0.500000                1.0        0.568182
# 996              1.0          0.000000                0.0        0.489796
# 997              1.0          0.333333                1.0        0.447368
# 998              1.0          0.333333                1.0        0.333333
# 999              1.0          0.333333                0.0        0.488889
#
#      m5_lex_den_ptxt  m6_lex_div_txt  m6_lex_div_ptxt  m7_stp_wd_txt  \
# 0           0.625000        1.000000         1.000000       0.789474
# 1           0.833333        1.000000         1.000000       0.619048
# 2           0.692308        1.000000         0.923077       0.722222
# 3           0.833333        1.000000         1.000000       0.600000
# 4           0.428571        1.000000         1.000000       0.523810
# ..               ...             ...              ...            ...
# 995         0.846154        0.866667         0.923077       0.600000
# 996         0.775862        0.762887         0.844828       0.628866
# 997         0.761905        0.868421         0.904762       0.631579
# 998         0.611111        0.933333         0.944444       0.633333
# 999         0.777778        0.844444         0.962963       0.600000
#
#      m7_stp_wd_ptxt
# 0          1.000000
# 1          1.000000
# 2          0.692308
# 3          1.000000
# 4          0.571429
# ..              ...
# 995        0.923077
# 996        0.844828
# 997        0.857143
# 998        0.722222
# 999        0.888889
#
# [5000 rows x 20 columns]

# %% [markdown]
# ### Metric 8: Average sentence length metric

# %%
average_sentence_length_metric(df, 'text','m8_sent_lgth_txt')
average_sentence_length_metric(df, 'processed_text','m8_sent_lgth_ptxt')
# Out:
#                                                   text human_sentiment  \
# 0    @switchfoot http://twitpic.com/2y1zl - Awww, t...        negative
# 1    is upset that he can't update his Facebook by ...        negative
# 2    @Kenichan I dived many times for the ball. Man...         neutral
# 3      my whole body feels itchy and like its on fire         negative
# 4    @nationwideclass no, it's not behaving at all....         neutral
# ..                                                 ...             ...
# 995  i love it! the berry scent is faint and delici...        positive
# 996  I use this almost every night and I wake up wi...         neutral
# 997  This mask is great! It smells delicious and my...        positive
# 998  These is similar to Vaseline with a tint of co...        negative
# 999  Feels like Vaseline, and has titanium dioxide ...        negative
#
#     text_type  length length_classification  \
# 0     twitter     115                medium
# 1     twitter     111                medium
# 2     twitter      89                medium
# 3     twitter      47                 short
# 4     twitter     111                medium
# ..        ...     ...                   ...
# 995    review     238                medium
# 996    review     511                  long
# 997    review     182                medium
# 998    review     151                medium
# 999    review     269                  long
#
#                                         processed_text  m1_abbrv_txt  \
# 0          aww bummer shoulda got david carr third day           1.0
# 1    upset cannot update facebook texting might cry...           1.0
# 2    dived many times for the ball managed save the...           1.0
# 3                     whole body feels itchy like fire           1.0
# 4                  no not behaving mad cannot see over           1.0
# ..                                                 ...           ...
# 995  love the berry scent faint delicious the produ...           1.0
# 996  use almost every night wake little left over t...           1.0
# 997  mask great smells delicious lips feel plump sm...           1.0
# 998  similar vaseline tint color but prettier jar o...           1.0
# 999  feels like vaseline titanium dioxide might car...           1.0
#
#      m1_abbrv_ptxt  m2_sp_mstke_txt  m2_sp_mstke_ptxt  ...  m4_gram_sent_txt  \
# 0              1.0         0.875000               1.0  ...          0.000000
# 1              1.0         1.000000               1.0  ...          0.000000
# 2              1.0         1.000000               1.0  ...          0.333333
# 3              1.0         1.000000               1.0  ...          0.000000
# 4              1.0         1.000000               1.0  ...          0.000000
# ..             ...              ...               ...  ...               ...
# 995            1.0         0.977273               1.0  ...          0.500000
# 996            1.0         0.979381               1.0  ...          0.000000
# 997            1.0         1.000000               1.0  ...          0.333333
# 998            1.0         0.933333               1.0  ...          0.333333
# 999            1.0         0.955556               1.0  ...          0.333333
#
#      m4_gram_sent_ptxt  m5_lex_den_txt  m5_lex_den_ptxt  m6_lex_div_txt  \
# 0                  0.0        0.454545         0.625000        1.000000
# 1                  0.0        0.363636         0.833333        1.000000
# 2                  1.0        0.500000         0.692308        1.000000
# 3                  0.0        0.500000         0.833333        1.000000
# 4                  0.0        0.500000         0.428571        1.000000
# ..                 ...             ...              ...             ...
# 995                1.0        0.568182         0.846154        0.866667
# 996                0.0        0.489796         0.775862        0.762887
# 997                1.0        0.447368         0.761905        0.868421
# 998                1.0        0.333333         0.611111        0.933333
# 999                0.0        0.488889         0.777778        0.844444
#
#      m6_lex_div_ptxt  m7_stp_wd_txt  m7_stp_wd_ptxt  m8_sent_lgth_txt  \
# 0           1.000000       0.789474        1.000000          0.744444
# 1           1.000000       0.619048        1.000000          0.722500
# 2           0.923077       0.722222        0.692308          0.802222
# 3           1.000000       0.600000        1.000000          1.000000
# 4           1.000000       0.523810        0.571429          0.791875
# ..               ...            ...             ...               ...
# 995         0.923077       0.600000        0.923077          0.405000
# 996         0.844828       0.628866        0.844828          0.290278
# 997         0.904762       0.631579        0.857143          0.595556
# 998         0.944444       0.633333        0.722222          0.664444
# 999         0.962963       0.600000        0.888889          0.402222
#
#      m8_sent_lgth_ptxt
# 0                  1.0
# 1                  1.0
# 2                  1.0
# 3                  1.0
# 4                  1.0
# ..                 ...
# 995                1.0
# 996                1.0
# 997                1.0
# 998                1.0
# 999                1.0
#
# [5000 rows x 22 columns]

# %% [markdown]
# ### Metric 9: Uppercased word metric

# %%
uppercased_word_metric(df, 'text','m9_upp_wd_txt')
uppercased_word_metric(df, 'processed_text','m9_upp_wd_ptxt')
# Out:
#                                                   text human_sentiment  \
# 0    @switchfoot http://twitpic.com/2y1zl - Awww, t...        negative
# 1    is upset that he can't update his Facebook by ...        negative
# 2    @Kenichan I dived many times for the ball. Man...         neutral
# 3      my whole body feels itchy and like its on fire         negative
# 4    @nationwideclass no, it's not behaving at all....         neutral
# ..                                                 ...             ...
# 995  i love it! the berry scent is faint and delici...        positive
# 996  I use this almost every night and I wake up wi...         neutral
# 997  This mask is great! It smells delicious and my...        positive
# 998  These is similar to Vaseline with a tint of co...        negative
# 999  Feels like Vaseline, and has titanium dioxide ...        negative
#
#     text_type  length length_classification  \
# 0     twitter     115                medium
# 1     twitter     111                medium
# 2     twitter      89                medium
# 3     twitter      47                 short
# 4     twitter     111                medium
# ..        ...     ...                   ...
# 995    review     238                medium
# 996    review     511                  long
# 997    review     182                medium
# 998    review     151                medium
# 999    review     269                  long
#
#                                         processed_text  m1_abbrv_txt  \
# 0          aww bummer shoulda got david carr third day           1.0
# 1    upset cannot update facebook texting might cry...           1.0
# 2    dived many times for the ball managed save the...           1.0
# 3                     whole body feels itchy like fire           1.0
# 4                  no not behaving mad cannot see over           1.0
# ..                                                 ...           ...
# 995  love the berry scent faint delicious the produ...           1.0
# 996  use almost every night wake little left over t...           1.0
# 997  mask great smells delicious lips feel plump sm...           1.0
# 998  similar vaseline tint color but prettier jar o...           1.0
# 999  feels like vaseline titanium dioxide might car...           1.0
#
#      m1_abbrv_ptxt  m2_sp_mstke_txt  m2_sp_mstke_ptxt  ...  m5_lex_den_txt  \
# 0              1.0         0.875000               1.0  ...        0.454545
# 1              1.0         1.000000               1.0  ...        0.363636
# 2              1.0         1.000000               1.0  ...        0.500000
# 3              1.0         1.000000               1.0  ...        0.500000
# 4              1.0         1.000000               1.0  ...        0.500000
# ..             ...              ...               ...  ...             ...
# 995            1.0         0.977273               1.0  ...        0.568182
# 996            1.0         0.979381               1.0  ...        0.489796
# 997            1.0         1.000000               1.0  ...        0.447368
# 998            1.0         0.933333               1.0  ...        0.333333
# 999            1.0         0.955556               1.0  ...        0.488889
#
#      m5_lex_den_ptxt  m6_lex_div_txt  m6_lex_div_ptxt  m7_stp_wd_txt  \
# 0           0.625000        1.000000         1.000000       0.789474
# 1           0.833333        1.000000         1.000000       0.619048
# 2           0.692308        1.000000         0.923077       0.722222
# 3           0.833333        1.000000         1.000000       0.600000
# 4           0.428571        1.000000         1.000000       0.523810
# ..               ...             ...              ...            ...
# 995         0.846154        0.866667         0.923077       0.600000
# 996         0.775862        0.762887         0.844828       0.628866
# 997         0.761905        0.868421         0.904762       0.631579
# 998         0.611111        0.933333         0.944444       0.633333
# 999         0.777778        0.844444         0.962963       0.600000
#
#      m7_stp_wd_ptxt  m8_sent_lgth_txt  m8_sent_lgth_ptxt  m9_upp_wd_txt  \
# 0          1.000000          0.744444                1.0       0.947368
# 1          1.000000          0.722500                1.0       1.000000
# 2          0.692308          0.802222                1.0       0.944444
# 3          1.000000          1.000000                1.0       1.000000
# 4          0.571429          0.791875                1.0       0.952381
# ..              ...               ...                ...            ...
# 995        0.923077          0.405000                1.0       1.000000
# 996        0.844828          0.290278                1.0       0.948454
# 997        0.857143          0.595556                1.0       0.947368
# 998        0.722222          0.664444                1.0       0.933333
# 999        0.888889          0.402222                1.0       0.955556
#
#      m9_upp_wd_ptxt
# 0               1.0
# 1               1.0
# 2               1.0
# 3               1.0
# 4               1.0
# ..              ...
# 995             1.0
# 996             1.0
# 997             1.0
# 998             1.0
# 999             1.0
#
# [5000 rows x 24 columns]

# %% [markdown]
# ### Metric 10: Punctuation metric

# %%
symbol_punctuation_metric(df,'text','m10_punct_txt')
symbol_punctuation_metric(df,'processed_text','m10_punct_ptxt')
# Out:
#                                                   text human_sentiment  \
# 0    @switchfoot http://twitpic.com/2y1zl - Awww, t...        negative
# 1    is upset that he can't update his Facebook by ...        negative
# 2    @Kenichan I dived many times for the ball. Man...         neutral
# 3      my whole body feels itchy and like its on fire         negative
# 4    @nationwideclass no, it's not behaving at all....         neutral
# ..                                                 ...             ...
# 995  i love it! the berry scent is faint and delici...        positive
# 996  I use this almost every night and I wake up wi...         neutral
# 997  This mask is great! It smells delicious and my...        positive
# 998  These is similar to Vaseline with a tint of co...        negative
# 999  Feels like Vaseline, and has titanium dioxide ...        negative
#
#     text_type  length length_classification  \
# 0     twitter     115                medium
# 1     twitter     111                medium
# 2     twitter      89                medium
# 3     twitter      47                 short
# 4     twitter     111                medium
# ..        ...     ...                   ...
# 995    review     238                medium
# 996    review     511                  long
# 997    review     182                medium
# 998    review     151                medium
# 999    review     269                  long
#
#                                         processed_text  m1_abbrv_txt  \
# 0          aww bummer shoulda got david carr third day           1.0
# 1    upset cannot update facebook texting might cry...           1.0
# 2    dived many times for the ball managed save the...           1.0
# 3                     whole body feels itchy like fire           1.0
# 4                  no not behaving mad cannot see over           1.0
# ..                                                 ...           ...
# 995  love the berry scent faint delicious the produ...           1.0
# 996  use almost every night wake little left over t...           1.0
# 997  mask great smells delicious lips feel plump sm...           1.0
# 998  similar vaseline tint color but prettier jar o...           1.0
# 999  feels like vaseline titanium dioxide might car...           1.0
#
#      m1_abbrv_ptxt  m2_sp_mstke_txt  m2_sp_mstke_ptxt  ...  m6_lex_div_txt  \
# 0              1.0         0.875000               1.0  ...        1.000000
# 1              1.0         1.000000               1.0  ...        1.000000
# 2              1.0         1.000000               1.0  ...        1.000000
# 3              1.0         1.000000               1.0  ...        1.000000
# 4              1.0         1.000000               1.0  ...        1.000000
# ..             ...              ...               ...  ...             ...
# 995            1.0         0.977273               1.0  ...        0.866667
# 996            1.0         0.979381               1.0  ...        0.762887
# 997            1.0         1.000000               1.0  ...        0.868421
# 998            1.0         0.933333               1.0  ...        0.933333
# 999            1.0         0.955556               1.0  ...        0.844444
#
#      m6_lex_div_ptxt  m7_stp_wd_txt  m7_stp_wd_ptxt  m8_sent_lgth_txt  \
# 0           1.000000       0.789474        1.000000          0.744444
# 1           1.000000       0.619048        1.000000          0.722500
# 2           0.923077       0.722222        0.692308          0.802222
# 3           1.000000       0.600000        1.000000          1.000000
# 4           1.000000       0.523810        0.571429          0.791875
# ..               ...            ...             ...               ...
# 995         0.923077       0.600000        0.923077          0.405000
# 996         0.844828       0.628866        0.844828          0.290278
# 997         0.904762       0.631579        0.857143          0.595556
# 998         0.944444       0.633333        0.722222          0.664444
# 999         0.962963       0.600000        0.888889          0.402222
#
#      m8_sent_lgth_ptxt  m9_upp_wd_txt  m9_upp_wd_ptxt  m10_punct_txt  \
# 0                  1.0       0.947368             1.0       0.875000
# 1                  1.0       1.000000             1.0       0.933333
# 2                  1.0       0.944444             1.0       0.957746
# 3                  1.0       1.000000             1.0       1.000000
# 4                  1.0       0.952381             1.0       0.900000
# ..                 ...            ...             ...            ...
# 995                1.0       1.000000             1.0       0.984536
# 996                1.0       0.948454             1.0       0.975904
# 997                1.0       0.947368             1.0       0.965517
# 998                1.0       0.933333             1.0       0.959016
# 999                1.0       0.955556             1.0       0.977778
#
#      m10_punct_ptxt
# 0               1.0
# 1               1.0
# 2               1.0
# 3               1.0
# 4               1.0
# ..              ...
# 995             1.0
# 996             1.0
# 997             1.0
# 998             1.0
# 999             1.0
#
# [5000 rows x 26 columns]

# %% [markdown]
# ## Context-independent Dimensions of Text Data Quality

# %% [markdown]
# ### Accuracy

# %%
# Accuracy for original text
accuracy_columns_txt= ['m1_abbrv_txt','m2_sp_mstke_txt','m3_unk_wds_txt','m4_gram_sent_txt']
column_average(df,accuracy_columns_txt,'dqd1_accuracy_txt')
# Out:
#                                                   text human_sentiment  \
# 0    @switchfoot http://twitpic.com/2y1zl - Awww, t...        negative
# 1    is upset that he can't update his Facebook by ...        negative
# 2    @Kenichan I dived many times for the ball. Man...         neutral
# 3      my whole body feels itchy and like its on fire         negative
# 4    @nationwideclass no, it's not behaving at all....         neutral
# ..                                                 ...             ...
# 995  i love it! the berry scent is faint and delici...        positive
# 996  I use this almost every night and I wake up wi...         neutral
# 997  This mask is great! It smells delicious and my...        positive
# 998  These is similar to Vaseline with a tint of co...        negative
# 999  Feels like Vaseline, and has titanium dioxide ...        negative
#
#     text_type  length length_classification  \
# 0     twitter     115                medium
# 1     twitter     111                medium
# 2     twitter      89                medium
# 3     twitter      47                 short
# 4     twitter     111                medium
# ..        ...     ...                   ...
# 995    review     238                medium
# 996    review     511                  long
# 997    review     182                medium
# 998    review     151                medium
# 999    review     269                  long
#
#                                         processed_text  m1_abbrv_txt  \
# 0          aww bummer shoulda got david carr third day           1.0
# 1    upset cannot update facebook texting might cry...           1.0
# 2    dived many times for the ball managed save the...           1.0
# 3                     whole body feels itchy like fire           1.0
# 4                  no not behaving mad cannot see over           1.0
# ..                                                 ...           ...
# 995  love the berry scent faint delicious the produ...           1.0
# 996  use almost every night wake little left over t...           1.0
# 997  mask great smells delicious lips feel plump sm...           1.0
# 998  similar vaseline tint color but prettier jar o...           1.0
# 999  feels like vaseline titanium dioxide might car...           1.0
#
#      m1_abbrv_ptxt  m2_sp_mstke_txt  m2_sp_mstke_ptxt  ...  m6_lex_div_ptxt  \
# 0              1.0         0.875000               1.0  ...         1.000000
# 1              1.0         1.000000               1.0  ...         1.000000
# 2              1.0         1.000000               1.0  ...         0.923077
# 3              1.0         1.000000               1.0  ...         1.000000
# 4              1.0         1.000000               1.0  ...         1.000000
# ..             ...              ...               ...  ...              ...
# 995            1.0         0.977273               1.0  ...         0.923077
# 996            1.0         0.979381               1.0  ...         0.844828
# 997            1.0         1.000000               1.0  ...         0.904762
# 998            1.0         0.933333               1.0  ...         0.944444
# 999            1.0         0.955556               1.0  ...         0.962963
#
#      m7_stp_wd_txt  m7_stp_wd_ptxt  m8_sent_lgth_txt  m8_sent_lgth_ptxt  \
# 0         0.789474        1.000000          0.744444                1.0
# 1         0.619048        1.000000          0.722500                1.0
# 2         0.722222        0.692308          0.802222                1.0
# 3         0.600000        1.000000          1.000000                1.0
# 4         0.523810        0.571429          0.791875                1.0
# ..             ...             ...               ...                ...
# 995       0.600000        0.923077          0.405000                1.0
# 996       0.628866        0.844828          0.290278                1.0
# 997       0.631579        0.857143          0.595556                1.0
# 998       0.633333        0.722222          0.664444                1.0
# 999       0.600000        0.888889          0.402222                1.0
#
#      m9_upp_wd_txt  m9_upp_wd_ptxt  m10_punct_txt  m10_punct_ptxt  \
# 0         0.947368             1.0       0.875000             1.0
# 1         1.000000             1.0       0.933333             1.0
# 2         0.944444             1.0       0.957746             1.0
# 3         1.000000             1.0       1.000000             1.0
# 4         0.952381             1.0       0.900000             1.0
# ..             ...             ...            ...             ...
# 995       1.000000             1.0       0.984536             1.0
# 996       0.948454             1.0       0.975904             1.0
# 997       0.947368             1.0       0.965517             1.0
# 998       0.933333             1.0       0.959016             1.0
# 999       0.955556             1.0       0.977778             1.0
#
#      dqd1_accuracy_txt
# 0             0.652961
# 1             0.738095
# 2             0.833333
# 3             0.750000
# 4             0.714286
# ..                 ...
# 995           0.863763
# 996           0.737113
# 997           0.833333
# 998           0.791667
# 999           0.811111
#
# [5000 rows x 27 columns]

# %%
# Accuracy for preprocessed text
accuracy_columns_ptxt= ['m1_abbrv_ptxt','m2_sp_mstke_ptxt','m3_unk_wds_ptxt','m4_gram_sent_ptxt']
column_average(df,accuracy_columns_ptxt,'dqd1_accuracy_ptxt')
# Out:
#                                                   text human_sentiment  \
# 0    @switchfoot http://twitpic.com/2y1zl - Awww, t...        negative
# 1    is upset that he can't update his Facebook by ...        negative
# 2    @Kenichan I dived many times for the ball. Man...         neutral
# 3      my whole body feels itchy and like its on fire         negative
# 4    @nationwideclass no, it's not behaving at all....         neutral
# ..                                                 ...             ...
# 995  i love it! the berry scent is faint and delici...        positive
# 996  I use this almost every night and I wake up wi...         neutral
# 997  This mask is great! It smells delicious and my...        positive
# 998  These is similar to Vaseline with a tint of co...        negative
# 999  Feels like Vaseline, and has titanium dioxide ...        negative
#
#     text_type  length length_classification  \
# 0     twitter     115                medium
# 1     twitter     111                medium
# 2     twitter      89                medium
# 3     twitter      47                 short
# 4     twitter     111                medium
# ..        ...     ...                   ...
# 995    review     238                medium
# 996    review     511                  long
# 997    review     182                medium
# 998    review     151                medium
# 999    review     269                  long
#
#                                         processed_text  m1_abbrv_txt  \
# 0          aww bummer shoulda got david carr third day           1.0
# 1    upset cannot update facebook texting might cry...           1.0
# 2    dived many times for the ball managed save the...           1.0
# 3                     whole body feels itchy like fire           1.0
# 4                  no not behaving mad cannot see over           1.0
# ..                                                 ...           ...
# 995  love the berry scent faint delicious the produ...           1.0
# 996  use almost every night wake little left over t...           1.0
# 997  mask great smells delicious lips feel plump sm...           1.0
# 998  similar vaseline tint color but prettier jar o...           1.0
# 999  feels like vaseline titanium dioxide might car...           1.0
#
#      m1_abbrv_ptxt  m2_sp_mstke_txt  m2_sp_mstke_ptxt  ...  m7_stp_wd_txt  \
# 0              1.0         0.875000               1.0  ...       0.789474
# 1              1.0         1.000000               1.0  ...       0.619048
# 2              1.0         1.000000               1.0  ...       0.722222
# 3              1.0         1.000000               1.0  ...       0.600000
# 4              1.0         1.000000               1.0  ...       0.523810
# ..             ...              ...               ...  ...            ...
# 995            1.0         0.977273               1.0  ...       0.600000
# 996            1.0         0.979381               1.0  ...       0.628866
# 997            1.0         1.000000               1.0  ...       0.631579
# 998            1.0         0.933333               1.0  ...       0.633333
# 999            1.0         0.955556               1.0  ...       0.600000
#
#      m7_stp_wd_ptxt  m8_sent_lgth_txt  m8_sent_lgth_ptxt  m9_upp_wd_txt  \
# 0          1.000000          0.744444                1.0       0.947368
# 1          1.000000          0.722500                1.0       1.000000
# 2          0.692308          0.802222                1.0       0.944444
# 3          1.000000          1.000000                1.0       1.000000
# 4          0.571429          0.791875                1.0       0.952381
# ..              ...               ...                ...            ...
# 995        0.923077          0.405000                1.0       1.000000
# 996        0.844828          0.290278                1.0       0.948454
# 997        0.857143          0.595556                1.0       0.947368
# 998        0.722222          0.664444                1.0       0.933333
# 999        0.888889          0.402222                1.0       0.955556
#
#      m9_upp_wd_ptxt  m10_punct_txt  m10_punct_ptxt  dqd1_accuracy_txt  \
# 0               1.0       0.875000             1.0           0.652961
# 1               1.0       0.933333             1.0           0.738095
# 2               1.0       0.957746             1.0           0.833333
# 3               1.0       1.000000             1.0           0.750000
# 4               1.0       0.900000             1.0           0.714286
# ..              ...            ...             ...                ...
# 995             1.0       0.984536             1.0           0.863763
# 996             1.0       0.975904             1.0           0.737113
# 997             1.0       0.965517             1.0           0.833333
# 998             1.0       0.959016             1.0           0.791667
# 999             1.0       0.977778             1.0           0.811111
#
#      dqd1_accuracy_ptxt
# 0                  0.75
# 1                  0.75
# 2                  1.00
# 3                  0.75
# 4                  0.75
# ..                  ...
# 995                1.00
# 996                0.75
# 997                1.00
# 998                1.00
# 999                0.75
#
# [5000 rows x 28 columns]

# %% [markdown]
# ### Completeness

# %%
# Completeness for original text
completeness_columns_txt= ['m5_lex_den_txt','m6_lex_div_txt','m7_stp_wd_txt']
column_average(df,completeness_columns_txt,'dqd2_completeness_txt')
# Out:
#                                                   text human_sentiment  \
# 0    @switchfoot http://twitpic.com/2y1zl - Awww, t...        negative
# 1    is upset that he can't update his Facebook by ...        negative
# 2    @Kenichan I dived many times for the ball. Man...         neutral
# 3      my whole body feels itchy and like its on fire         negative
# 4    @nationwideclass no, it's not behaving at all....         neutral
# ..                                                 ...             ...
# 995  i love it! the berry scent is faint and delici...        positive
# 996  I use this almost every night and I wake up wi...         neutral
# 997  This mask is great! It smells delicious and my...        positive
# 998  These is similar to Vaseline with a tint of co...        negative
# 999  Feels like Vaseline, and has titanium dioxide ...        negative
#
#     text_type  length length_classification  \
# 0     twitter     115                medium
# 1     twitter     111                medium
# 2     twitter      89                medium
# 3     twitter      47                 short
# 4     twitter     111                medium
# ..        ...     ...                   ...
# 995    review     238                medium
# 996    review     511                  long
# 997    review     182                medium
# 998    review     151                medium
# 999    review     269                  long
#
#                                         processed_text  m1_abbrv_txt  \
# 0          aww bummer shoulda got david carr third day           1.0
# 1    upset cannot update facebook texting might cry...           1.0
# 2    dived many times for the ball managed save the...           1.0
# 3                     whole body feels itchy like fire           1.0
# 4                  no not behaving mad cannot see over           1.0
# ..                                                 ...           ...
# 995  love the berry scent faint delicious the produ...           1.0
# 996  use almost every night wake little left over t...           1.0
# 997  mask great smells delicious lips feel plump sm...           1.0
# 998  similar vaseline tint color but prettier jar o...           1.0
# 999  feels like vaseline titanium dioxide might car...           1.0
#
#      m1_abbrv_ptxt  m2_sp_mstke_txt  m2_sp_mstke_ptxt  ...  m7_stp_wd_ptxt  \
# 0              1.0         0.875000               1.0  ...        1.000000
# 1              1.0         1.000000               1.0  ...        1.000000
# 2              1.0         1.000000               1.0  ...        0.692308
# 3              1.0         1.000000               1.0  ...        1.000000
# 4              1.0         1.000000               1.0  ...        0.571429
# ..             ...              ...               ...  ...             ...
# 995            1.0         0.977273               1.0  ...        0.923077
# 996            1.0         0.979381               1.0  ...        0.844828
# 997            1.0         1.000000               1.0  ...        0.857143
# 998            1.0         0.933333               1.0  ...        0.722222
# 999            1.0         0.955556               1.0  ...        0.888889
#
#      m8_sent_lgth_txt  m8_sent_lgth_ptxt  m9_upp_wd_txt  m9_upp_wd_ptxt  \
# 0            0.744444                1.0       0.947368             1.0
# 1            0.722500                1.0       1.000000             1.0
# 2            0.802222                1.0       0.944444             1.0
# 3            1.000000                1.0       1.000000             1.0
# 4            0.791875                1.0       0.952381             1.0
# ..                ...                ...            ...             ...
# 995          0.405000                1.0       1.000000             1.0
# 996          0.290278                1.0       0.948454             1.0
# 997          0.595556                1.0       0.947368             1.0
# 998          0.664444                1.0       0.933333             1.0
# 999          0.402222                1.0       0.955556             1.0
#
#      m10_punct_txt  m10_punct_ptxt  dqd1_accuracy_txt  dqd1_accuracy_ptxt  \
# 0         0.875000             1.0           0.652961                0.75
# 1         0.933333             1.0           0.738095                0.75
# 2         0.957746             1.0           0.833333                1.00
# 3         1.000000             1.0           0.750000                0.75
# 4         0.900000             1.0           0.714286                0.75
# ..             ...             ...                ...                 ...
# 995       0.984536             1.0           0.863763                1.00
# 996       0.975904             1.0           0.737113                0.75
# 997       0.965517             1.0           0.833333                1.00
# 998       0.959016             1.0           0.791667                1.00
# 999       0.977778             1.0           0.811111                0.75
#
#      dqd2_completeness_txt
# 0                 0.748006
# 1                 0.660895
# 2                 0.740741
# 3                 0.700000
# 4                 0.674603
# ..                     ...
# 995               0.678283
# 996               0.627183
# 997               0.649123
# 998               0.633333
# 999               0.644444
#
# [5000 rows x 29 columns]

# %%
# Completeness for preprocessed text
completeness_columns_ptxt= ['m5_lex_den_ptxt','m6_lex_div_ptxt','m7_stp_wd_ptxt']
column_average(df,completeness_columns_ptxt,'dqd2_completeness_ptxt')
# Out:
#                                                   text human_sentiment  \
# 0    @switchfoot http://twitpic.com/2y1zl - Awww, t...        negative
# 1    is upset that he can't update his Facebook by ...        negative
# 2    @Kenichan I dived many times for the ball. Man...         neutral
# 3      my whole body feels itchy and like its on fire         negative
# 4    @nationwideclass no, it's not behaving at all....         neutral
# ..                                                 ...             ...
# 995  i love it! the berry scent is faint and delici...        positive
# 996  I use this almost every night and I wake up wi...         neutral
# 997  This mask is great! It smells delicious and my...        positive
# 998  These is similar to Vaseline with a tint of co...        negative
# 999  Feels like Vaseline, and has titanium dioxide ...        negative
#
#     text_type  length length_classification  \
# 0     twitter     115                medium
# 1     twitter     111                medium
# 2     twitter      89                medium
# 3     twitter      47                 short
# 4     twitter     111                medium
# ..        ...     ...                   ...
# 995    review     238                medium
# 996    review     511                  long
# 997    review     182                medium
# 998    review     151                medium
# 999    review     269                  long
#
#                                         processed_text  m1_abbrv_txt  \
# 0          aww bummer shoulda got david carr third day           1.0
# 1    upset cannot update facebook texting might cry...           1.0
# 2    dived many times for the ball managed save the...           1.0
# 3                     whole body feels itchy like fire           1.0
# 4                  no not behaving mad cannot see over           1.0
# ..                                                 ...           ...
# 995  love the berry scent faint delicious the produ...           1.0
# 996  use almost every night wake little left over t...           1.0
# 997  mask great smells delicious lips feel plump sm...           1.0
# 998  similar vaseline tint color but prettier jar o...           1.0
# 999  feels like vaseline titanium dioxide might car...           1.0
#
#      m1_abbrv_ptxt  m2_sp_mstke_txt  m2_sp_mstke_ptxt  ...  m8_sent_lgth_txt  \
# 0              1.0         0.875000               1.0  ...          0.744444
# 1              1.0         1.000000               1.0  ...          0.722500
# 2              1.0         1.000000               1.0  ...          0.802222
# 3              1.0         1.000000               1.0  ...          1.000000
# 4              1.0         1.000000               1.0  ...          0.791875
# ..             ...              ...               ...  ...               ...
# 995            1.0         0.977273               1.0  ...          0.405000
# 996            1.0         0.979381               1.0  ...          0.290278
# 997            1.0         1.000000               1.0  ...          0.595556
# 998            1.0         0.933333               1.0  ...          0.664444
# 999            1.0         0.955556               1.0  ...          0.402222
#
#      m8_sent_lgth_ptxt  m9_upp_wd_txt  m9_upp_wd_ptxt  m10_punct_txt  \
# 0                  1.0       0.947368             1.0       0.875000
# 1                  1.0       1.000000             1.0       0.933333
# 2                  1.0       0.944444             1.0       0.957746
# 3                  1.0       1.000000             1.0       1.000000
# 4                  1.0       0.952381             1.0       0.900000
# ..                 ...            ...             ...            ...
# 995                1.0       1.000000             1.0       0.984536
# 996                1.0       0.948454             1.0       0.975904
# 997                1.0       0.947368             1.0       0.965517
# 998                1.0       0.933333             1.0       0.959016
# 999                1.0       0.955556             1.0       0.977778
#
#      m10_punct_ptxt  dqd1_accuracy_txt  dqd1_accuracy_ptxt  \
# 0               1.0           0.652961                0.75
# 1               1.0           0.738095                0.75
# 2               1.0           0.833333                1.00
# 3               1.0           0.750000                0.75
# 4               1.0           0.714286                0.75
# ..              ...                ...                 ...
# 995             1.0           0.863763                1.00
# 996             1.0           0.737113                0.75
# 997             1.0           0.833333                1.00
# 998             1.0           0.791667                1.00
# 999             1.0           0.811111                0.75
#
#      dqd2_completeness_txt  dqd2_completeness_ptxt
# 0                 0.748006                0.875000
# 1                 0.660895                0.944444
# 2                 0.740741                0.769231
# 3                 0.700000                0.944444
# 4                 0.674603                0.666667
# ..                     ...                     ...
# 995               0.678283                0.897436
# 996               0.627183                0.821839
# 997               0.649123                0.841270
# 998               0.633333                0.759259
# 999               0.644444                0.876543
#
# [5000 rows x 30 columns]

# %% [markdown]
# ### Consistency

# %%
# Consistency for original text
consistency_columns_txt= ['m8_sent_lgth_txt','m9_upp_wd_txt','m10_punct_txt']
column_average(df,consistency_columns_txt,'dqd3_consistency_txt')
# Out:
#                                                   text human_sentiment  \
# 0    @switchfoot http://twitpic.com/2y1zl - Awww, t...        negative
# 1    is upset that he can't update his Facebook by ...        negative
# 2    @Kenichan I dived many times for the ball. Man...         neutral
# 3      my whole body feels itchy and like its on fire         negative
# 4    @nationwideclass no, it's not behaving at all....         neutral
# ..                                                 ...             ...
# 995  i love it! the berry scent is faint and delici...        positive
# 996  I use this almost every night and I wake up wi...         neutral
# 997  This mask is great! It smells delicious and my...        positive
# 998  These is similar to Vaseline with a tint of co...        negative
# 999  Feels like Vaseline, and has titanium dioxide ...        negative
#
#     text_type  length length_classification  \
# 0     twitter     115                medium
# 1     twitter     111                medium
# 2     twitter      89                medium
# 3     twitter      47                 short
# 4     twitter     111                medium
# ..        ...     ...                   ...
# 995    review     238                medium
# 996    review     511                  long
# 997    review     182                medium
# 998    review     151                medium
# 999    review     269                  long
#
#                                         processed_text  m1_abbrv_txt  \
# 0          aww bummer shoulda got david carr third day           1.0
# 1    upset cannot update facebook texting might cry...           1.0
# 2    dived many times for the ball managed save the...           1.0
# 3                     whole body feels itchy like fire           1.0
# 4                  no not behaving mad cannot see over           1.0
# ..                                                 ...           ...
# 995  love the berry scent faint delicious the produ...           1.0
# 996  use almost every night wake little left over t...           1.0
# 997  mask great smells delicious lips feel plump sm...           1.0
# 998  similar vaseline tint color but prettier jar o...           1.0
# 999  feels like vaseline titanium dioxide might car...           1.0
#
#      m1_abbrv_ptxt  m2_sp_mstke_txt  m2_sp_mstke_ptxt  ...  m8_sent_lgth_ptxt  \
# 0              1.0         0.875000               1.0  ...                1.0
# 1              1.0         1.000000               1.0  ...                1.0
# 2              1.0         1.000000               1.0  ...                1.0
# 3              1.0         1.000000               1.0  ...                1.0
# 4              1.0         1.000000               1.0  ...                1.0
# ..             ...              ...               ...  ...                ...
# 995            1.0         0.977273               1.0  ...                1.0
# 996            1.0         0.979381               1.0  ...                1.0
# 997            1.0         1.000000               1.0  ...                1.0
# 998            1.0         0.933333               1.0  ...                1.0
# 999            1.0         0.955556               1.0  ...                1.0
#
#      m9_upp_wd_txt  m9_upp_wd_ptxt  m10_punct_txt  m10_punct_ptxt  \
# 0         0.947368             1.0       0.875000             1.0
# 1         1.000000             1.0       0.933333             1.0
# 2         0.944444             1.0       0.957746             1.0
# 3         1.000000             1.0       1.000000             1.0
# 4         0.952381             1.0       0.900000             1.0
# ..             ...             ...            ...             ...
# 995       1.000000             1.0       0.984536             1.0
# 996       0.948454             1.0       0.975904             1.0
# 997       0.947368             1.0       0.965517             1.0
# 998       0.933333             1.0       0.959016             1.0
# 999       0.955556             1.0       0.977778             1.0
#
#      dqd1_accuracy_txt  dqd1_accuracy_ptxt  dqd2_completeness_txt  \
# 0             0.652961                0.75               0.748006
# 1             0.738095                0.75               0.660895
# 2             0.833333                1.00               0.740741
# 3             0.750000                0.75               0.700000
# 4             0.714286                0.75               0.674603
# ..                 ...                 ...                    ...
# 995           0.863763                1.00               0.678283
# 996           0.737113                0.75               0.627183
# 997           0.833333                1.00               0.649123
# 998           0.791667                1.00               0.633333
# 999           0.811111                0.75               0.644444
#
#      dqd2_completeness_ptxt  dqd3_consistency_txt
# 0                  0.875000              0.855604
# 1                  0.944444              0.885278
# 2                  0.769231              0.901471
# 3                  0.944444              1.000000
# 4                  0.666667              0.881419
# ..                      ...                   ...
# 995                0.897436              0.796512
# 996                0.821839              0.738212
# 997                0.841270              0.836147
# 998                0.759259              0.852265
# 999                0.876543              0.778519
#
# [5000 rows x 31 columns]

# %%
# Consistency for preprocessed text
consistency_columns_ptxt= ['m8_sent_lgth_ptxt','m9_upp_wd_ptxt','m10_punct_ptxt']
column_average(df,consistency_columns_ptxt,'dqd3_consistency_ptxt')
# Out:
#                                                   text human_sentiment  \
# 0    @switchfoot http://twitpic.com/2y1zl - Awww, t...        negative
# 1    is upset that he can't update his Facebook by ...        negative
# 2    @Kenichan I dived many times for the ball. Man...         neutral
# 3      my whole body feels itchy and like its on fire         negative
# 4    @nationwideclass no, it's not behaving at all....         neutral
# ..                                                 ...             ...
# 995  i love it! the berry scent is faint and delici...        positive
# 996  I use this almost every night and I wake up wi...         neutral
# 997  This mask is great! It smells delicious and my...        positive
# 998  These is similar to Vaseline with a tint of co...        negative
# 999  Feels like Vaseline, and has titanium dioxide ...        negative
#
#     text_type  length length_classification  \
# 0     twitter     115                medium
# 1     twitter     111                medium
# 2     twitter      89                medium
# 3     twitter      47                 short
# 4     twitter     111                medium
# ..        ...     ...                   ...
# 995    review     238                medium
# 996    review     511                  long
# 997    review     182                medium
# 998    review     151                medium
# 999    review     269                  long
#
#                                         processed_text  m1_abbrv_txt  \
# 0          aww bummer shoulda got david carr third day           1.0
# 1    upset cannot update facebook texting might cry...           1.0
# 2    dived many times for the ball managed save the...           1.0
# 3                     whole body feels itchy like fire           1.0
# 4                  no not behaving mad cannot see over           1.0
# ..                                                 ...           ...
# 995  love the berry scent faint delicious the produ...           1.0
# 996  use almost every night wake little left over t...           1.0
# 997  mask great smells delicious lips feel plump sm...           1.0
# 998  similar vaseline tint color but prettier jar o...           1.0
# 999  feels like vaseline titanium dioxide might car...           1.0
#
#      m1_abbrv_ptxt  m2_sp_mstke_txt  m2_sp_mstke_ptxt  ...  m9_upp_wd_txt  \
# 0              1.0         0.875000               1.0  ...       0.947368
# 1              1.0         1.000000               1.0  ...       1.000000
# 2              1.0         1.000000               1.0  ...       0.944444
# 3              1.0         1.000000               1.0  ...       1.000000
# 4              1.0         1.000000               1.0  ...       0.952381
# ..             ...              ...               ...  ...            ...
# 995            1.0         0.977273               1.0  ...       1.000000
# 996            1.0         0.979381               1.0  ...       0.948454
# 997            1.0         1.000000               1.0  ...       0.947368
# 998            1.0         0.933333               1.0  ...       0.933333
# 999            1.0         0.955556               1.0  ...       0.955556
#
#      m9_upp_wd_ptxt  m10_punct_txt  m10_punct_ptxt  dqd1_accuracy_txt  \
# 0               1.0       0.875000             1.0           0.652961
# 1               1.0       0.933333             1.0           0.738095
# 2               1.0       0.957746             1.0           0.833333
# 3               1.0       1.000000             1.0           0.750000
# 4               1.0       0.900000             1.0           0.714286
# ..              ...            ...             ...                ...
# 995             1.0       0.984536             1.0           0.863763
# 996             1.0       0.975904             1.0           0.737113
# 997             1.0       0.965517             1.0           0.833333
# 998             1.0       0.959016             1.0           0.791667
# 999             1.0       0.977778             1.0           0.811111
#
#      dqd1_accuracy_ptxt  dqd2_completeness_txt  dqd2_completeness_ptxt  \
# 0                  0.75               0.748006                0.875000
# 1                  0.75               0.660895                0.944444
# 2                  1.00               0.740741                0.769231
# 3                  0.75               0.700000                0.944444
# 4                  0.75               0.674603                0.666667
# ..                  ...                    ...                     ...
# 995                1.00               0.678283                0.897436
# 996                0.75               0.627183                0.821839
# 997                1.00               0.649123                0.841270
# 998                1.00               0.633333                0.759259
# 999                0.75               0.644444                0.876543
#
#      dqd3_consistency_txt  dqd3_consistency_ptxt
# 0                0.855604                    1.0
# 1                0.885278                    1.0
# 2                0.901471                    1.0
# 3                1.000000                    1.0
# 4                0.881419                    1.0
# ..                    ...                    ...
# 995              0.796512                    1.0
# 996              0.738212                    1.0
# 997              0.836147                    1.0
# 998              0.852265                    1.0
# 999              0.778519                    1.0
#
# [5000 rows x 32 columns]

# %% [markdown]
# ## Context-independent Measurement of Text Data Quality

# %%
# Context-independent Measurement of Text Data Quality for original text
DQ_columns_txt= ['m1_abbrv_txt','m2_sp_mstke_txt','m3_unk_wds_txt','m4_gram_sent_txt','m5_lex_den_txt','m6_lex_div_txt','m7_stp_wd_txt','m8_sent_lgth_txt','m9_upp_wd_txt','m10_punct_txt']
column_average(df,DQ_columns_txt,'TDQ_txt')
# Out:
#                                                   text human_sentiment  \
# 0    @switchfoot http://twitpic.com/2y1zl - Awww, t...        negative
# 1    is upset that he can't update his Facebook by ...        negative
# 2    @Kenichan I dived many times for the ball. Man...         neutral
# 3      my whole body feels itchy and like its on fire         negative
# 4    @nationwideclass no, it's not behaving at all....         neutral
# ..                                                 ...             ...
# 995  i love it! the berry scent is faint and delici...        positive
# 996  I use this almost every night and I wake up wi...         neutral
# 997  This mask is great! It smells delicious and my...        positive
# 998  These is similar to Vaseline with a tint of co...        negative
# 999  Feels like Vaseline, and has titanium dioxide ...        negative
#
#     text_type  length length_classification  \
# 0     twitter     115                medium
# 1     twitter     111                medium
# 2     twitter      89                medium
# 3     twitter      47                 short
# 4     twitter     111                medium
# ..        ...     ...                   ...
# 995    review     238                medium
# 996    review     511                  long
# 997    review     182                medium
# 998    review     151                medium
# 999    review     269                  long
#
#                                         processed_text  m1_abbrv_txt  \
# 0          aww bummer shoulda got david carr third day           1.0
# 1    upset cannot update facebook texting might cry...           1.0
# 2    dived many times for the ball managed save the...           1.0
# 3                     whole body feels itchy like fire           1.0
# 4                  no not behaving mad cannot see over           1.0
# ..                                                 ...           ...
# 995  love the berry scent faint delicious the produ...           1.0
# 996  use almost every night wake little left over t...           1.0
# 997  mask great smells delicious lips feel plump sm...           1.0
# 998  similar vaseline tint color but prettier jar o...           1.0
# 999  feels like vaseline titanium dioxide might car...           1.0
#
#      m1_abbrv_ptxt  m2_sp_mstke_txt  m2_sp_mstke_ptxt  ...  m9_upp_wd_ptxt  \
# 0              1.0         0.875000               1.0  ...             1.0
# 1              1.0         1.000000               1.0  ...             1.0
# 2              1.0         1.000000               1.0  ...             1.0
# 3              1.0         1.000000               1.0  ...             1.0
# 4              1.0         1.000000               1.0  ...             1.0
# ..             ...              ...               ...  ...             ...
# 995            1.0         0.977273               1.0  ...             1.0
# 996            1.0         0.979381               1.0  ...             1.0
# 997            1.0         1.000000               1.0  ...             1.0
# 998            1.0         0.933333               1.0  ...             1.0
# 999            1.0         0.955556               1.0  ...             1.0
#
#      m10_punct_txt  m10_punct_ptxt  dqd1_accuracy_txt  dqd1_accuracy_ptxt  \
# 0         0.875000             1.0           0.652961                0.75
# 1         0.933333             1.0           0.738095                0.75
# 2         0.957746             1.0           0.833333                1.00
# 3         1.000000             1.0           0.750000                0.75
# 4         0.900000             1.0           0.714286                0.75
# ..             ...             ...                ...                 ...
# 995       0.984536             1.0           0.863763                1.00
# 996       0.975904             1.0           0.737113                0.75
# 997       0.965517             1.0           0.833333                1.00
# 998       0.959016             1.0           0.791667                1.00
# 999       0.977778             1.0           0.811111                0.75
#
#      dqd2_completeness_txt  dqd2_completeness_ptxt  dqd3_consistency_txt  \
# 0                 0.748006                0.875000              0.855604
# 1                 0.660895                0.944444              0.885278
# 2                 0.740741                0.769231              0.901471
# 3                 0.700000                0.944444              1.000000
# 4                 0.674603                0.666667              0.881419
# ..                     ...                     ...                   ...
# 995               0.678283                0.897436              0.796512
# 996               0.627183                0.821839              0.738212
# 997               0.649123                0.841270              0.836147
# 998               0.633333                0.759259              0.852265
# 999               0.644444                0.876543              0.778519
#
#      dqd3_consistency_ptxt   TDQ_txt
# 0                      1.0  0.742267
# 1                      1.0  0.759090
# 2                      1.0  0.825997
# 3                      1.0  0.810000
# 4                      1.0  0.752521
# ..                     ...       ...
# 995                    1.0  0.787944
# 996                    1.0  0.704464
# 997                    1.0  0.778914
# 998                    1.0  0.762346
# 999                    1.0  0.751333
#
# [5000 rows x 33 columns]

# %%
# Context-independent Measurement of Text Data Quality for preprocessed text
DQ_columns_ptxt= ['m1_abbrv_ptxt','m2_sp_mstke_ptxt','m3_unk_wds_ptxt','m4_gram_sent_ptxt','m5_lex_den_ptxt','m6_lex_div_ptxt','m7_stp_wd_ptxt','m8_sent_lgth_ptxt','m9_upp_wd_ptxt','m10_punct_ptxt']
column_average(df,DQ_columns_ptxt,'TDQ_ptxt')
# Out:
#                                                   text human_sentiment  \
# 0    @switchfoot http://twitpic.com/2y1zl - Awww, t...        negative
# 1    is upset that he can't update his Facebook by ...        negative
# 2    @Kenichan I dived many times for the ball. Man...         neutral
# 3      my whole body feels itchy and like its on fire         negative
# 4    @nationwideclass no, it's not behaving at all....         neutral
# ..                                                 ...             ...
# 995  i love it! the berry scent is faint and delici...        positive
# 996  I use this almost every night and I wake up wi...         neutral
# 997  This mask is great! It smells delicious and my...        positive
# 998  These is similar to Vaseline with a tint of co...        negative
# 999  Feels like Vaseline, and has titanium dioxide ...        negative
#
#     text_type  length length_classification  \
# 0     twitter     115                medium
# 1     twitter     111                medium
# 2     twitter      89                medium
# 3     twitter      47                 short
# 4     twitter     111                medium
# ..        ...     ...                   ...
# 995    review     238                medium
# 996    review     511                  long
# 997    review     182                medium
# 998    review     151                medium
# 999    review     269                  long
#
#                                         processed_text  m1_abbrv_txt  \
# 0          aww bummer shoulda got david carr third day           1.0
# 1    upset cannot update facebook texting might cry...           1.0
# 2    dived many times for the ball managed save the...           1.0
# 3                     whole body feels itchy like fire           1.0
# 4                  no not behaving mad cannot see over           1.0
# ..                                                 ...           ...
# 995  love the berry scent faint delicious the produ...           1.0
# 996  use almost every night wake little left over t...           1.0
# 997  mask great smells delicious lips feel plump sm...           1.0
# 998  similar vaseline tint color but prettier jar o...           1.0
# 999  feels like vaseline titanium dioxide might car...           1.0
#
#      m1_abbrv_ptxt  m2_sp_mstke_txt  m2_sp_mstke_ptxt  ...  m10_punct_txt  \
# 0              1.0         0.875000               1.0  ...       0.875000
# 1              1.0         1.000000               1.0  ...       0.933333
# 2              1.0         1.000000               1.0  ...       0.957746
# 3              1.0         1.000000               1.0  ...       1.000000
# 4              1.0         1.000000               1.0  ...       0.900000
# ..             ...              ...               ...  ...            ...
# 995            1.0         0.977273               1.0  ...       0.984536
# 996            1.0         0.979381               1.0  ...       0.975904
# 997            1.0         1.000000               1.0  ...       0.965517
# 998            1.0         0.933333               1.0  ...       0.959016
# 999            1.0         0.955556               1.0  ...       0.977778
#
#      m10_punct_ptxt  dqd1_accuracy_txt  dqd1_accuracy_ptxt  \
# 0               1.0           0.652961                0.75
# 1               1.0           0.738095                0.75
# 2               1.0           0.833333                1.00
# 3               1.0           0.750000                0.75
# 4               1.0           0.714286                0.75
# ..              ...                ...                 ...
# 995             1.0           0.863763                1.00
# 996             1.0           0.737113                0.75
# 997             1.0           0.833333                1.00
# 998             1.0           0.791667                1.00
# 999             1.0           0.811111                0.75
#
#      dqd2_completeness_txt  dqd2_completeness_ptxt  dqd3_consistency_txt  \
# 0                 0.748006                0.875000              0.855604
# 1                 0.660895                0.944444              0.885278
# 2                 0.740741                0.769231              0.901471
# 3                 0.700000                0.944444              1.000000
# 4                 0.674603                0.666667              0.881419
# ..                     ...                     ...                   ...
# 995               0.678283                0.897436              0.796512
# 996               0.627183                0.821839              0.738212
# 997               0.649123                0.841270              0.836147
# 998               0.633333                0.759259              0.852265
# 999               0.644444                0.876543              0.778519
#
#      dqd3_consistency_ptxt   TDQ_txt  TDQ_ptxt
# 0                      1.0  0.742267  0.862500
# 1                      1.0  0.759090  0.883333
# 2                      1.0  0.825997  0.930769
# 3                      1.0  0.810000  0.883333
# 4                      1.0  0.752521  0.800000
# ..                     ...       ...       ...
# 995                    1.0  0.787944  0.969231
# 996                    1.0  0.704464  0.846552
# 997                    1.0  0.778914  0.952381
# 998                    1.0  0.762346  0.927778
# 999                    1.0  0.751333  0.862963
#
# [5000 rows x 34 columns]

# %%
# Create pickle file
picklefile = open('Data/Results/dataset_TDQ.pkl', 'wb')
pickle.dump(df, picklefile)
picklefile.close()

# %% [markdown]
# ## Sentiment Analysis

# %%
# Upload pickle file with dataset
with open(Path('dataset_TDQ.pkl').parent/'Data/Results/dataset_TDQ.pkl', 'rb') as file:
        df = pickle.load(file)

# %%
# Load Sentiment Analysis Model
sentiment = SentimentIntensityAnalyzer()

# %%
# Sentiment Analysis for original text
sentiment_txt=[]
for value in df['text']:
    sent_value = sentiment.polarity_scores(value)['compound']
    # Convert value to classification
    if sent_value >= 0.05:
        sent_value='positive'
    elif sent_value <= -0.05:
        sent_value = 'negative'
    else:
        sent_value ='neutral'
    sentiment_txt.append(sent_value)
df['sentiment_txt']= sentiment_txt

# %%
# Sentiment Analysis for preprocessed text
sentiment_ptxt=[]
for value in df['processed_text']:
    sent_value = sentiment.polarity_scores(value)['compound']
    # Convert value to classification
    if sent_value >= 0.05:
        sent_value='positive'
    elif sent_value <= -0.05:
        sent_value ='negative'
    else:
        sent_value ='neutral'
    sentiment_ptxt.append(sent_value)
df['sentiment_ptxt']= sentiment_ptxt

# %% [markdown]
# ## Sentiment Analysis Performance

# %%
df['comparison_txt'] = df['human_sentiment'] == df['sentiment_txt']
df['comparison_ptxt'] = df['human_sentiment'] == df['sentiment_ptxt']

# %%
df['comparison_txt'] = df['comparison_txt'].astype(int)
df['comparison_ptxt']= df['comparison_ptxt'].astype(int)

# %% [markdown]
# ## Dataset to analyze

# %%
df.to_excel('Data/Results/dataset_to_analyze.xlsx', index=False)

# %%
# Create pickle file
picklefile = open('Data/Results/dataset_to_analyze.pkl', 'wb')
pickle.dump(df, picklefile)
picklefile.close()
